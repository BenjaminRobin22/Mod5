# %%
# This is Ben Robin's 8.1 & 8.2

f'{17.489:.2f}'
# Out:
# '17.49'

# %%
f'{10:d}'
# Out:
# '10'

# %%
f'{65:c} {97:c}'
# Out:
# 'A a'

# %%
f'{"hello":s} {7}'
# Out:
# 'hello 7'

# %%
from decimal import Decimal

# %%
f'{Decimal("10000000000000000000.0"):.3f}'
# Out:
# '10000000000000000000.000'

# %%
f'{Decimal("10000000000000000000.0"):.3e}'
# Out:
# '1.000e+19'

# %%
#8.2 self check

# %%
print(f'{58:c}{45:c}{41:c}')
# Out:
# :-)

# %%
# 8.2.2 Ben Robin

# %%
f'[{27:10d}]'
# Out:
# '[        27]'

# %%
f'[{3.5:10f}]'
# Out:
# '[  3.500000]'

# %%
f'[{"hello":10}]'
# Out:
# '[hello     ]'

# %%
f'[{27:<15d}]'
# Out:
# '[27             ]'

# %%
f'[{3.5:<15f}]'
# Out:
# '[3.500000       ]'

# %%
f'[{"hello":<15}]'
# Out:
# '[hello          ]'

# %%
f'[{27:^7d}]'
# Out:
# '[  27   ]'

# %%
f'[{3.5:^7.1f}]'
# Out:
# '[  3.5  ]'

# %%
f'[{"hello":^7}]'
# Out:
# '[ hello ]'

# %%
#8.2.2 Self Check Ben Robin 
print(f'[{"Amanda":>10}]\n[{"Amanda":^10}]\n[{"Amanda":<10}]')
# Out:
# [    Amanda]
# [  Amanda  ]
# [Amanda    ]

# %%
#8.2.3 Ben Robin

# %%
f'[{27:+10d}]'
# Out:
# '[       +27]'

# %%
f'[{27:+010d}]'
# Out:
# '[+000000027]'

# %%
print(f'{27:d}\n{27: d}\n{-27: d}')
# Out:
# 27
#  27
# -27

# %%
f'{12345678:,d}'
# Out:
# '12,345,678'

# %%
f'{123456.78:,.2f}'
# Out:
# '123,456.78'

# %%
print(f'{10240.473:+10,.2f}\n{-3210.9521:+10,.2f}')
# Out:
# +10,240.47
#  -3,210.95

# %%
'{:.2f}'.format(17.489)
# Out:
# '17.49'

# %%
'{} {}'.format('Amanda','Cyan')
# Out:
# 'Amanda Cyan'

# %%
'{0} {0} {1}'.format('Happy', 'Birthday')
# Out:
# 'Happy Happy Birthday'

# %%
'{first} {last}'.format(first='Amanda',last='Gray')
# Out:
# 'Amanda Gray'

# %%
'{last} {first}'.format(last='Gray',first='Amanda')
# Out:
# 'Gray Amanda'

# %%
#8.2.4 self check Ben Robin 
print('{:c}{:c}{:c}'.format(58,45,41))
# Out:
# :-)

# %%
print('[{0:>10}]\n[{0:^10}]\n[{0:<10}]'.format('Amanda'))
# Out:
# [    Amanda]
# [  Amanda  ]
# [Amanda    ]

# %%
print('{:+10,.2f}\n{:+10.2f}'.format(10240.473, -3210.9521))
# Out:
# +10,240.47
#   -3210.95

# %%
# 8.3 Ben Robin 
s1 = 'happy'
s2 = 'birthday'
s1 += ' ' + s2
s1
# Out:
# 'happy birthday'

# %%
symbol = '>'
symbol *= 5
symbol
# Out:
# '>>>>>'

# %%
name = 'Pam'
name += ' Black'
bar = '*'
bar *= len(name)
print(f'{bar}\n{name}\n{bar}')
# Out:
# *********
# Pam Black
# *********

# %%
# Ben Robin 8.4

# %%
sentence = '\t \n This is a test string. \t\t \n'
sentence.strip()
# Out:
# 'This is a test string.'

# %%
sentence.lstrip()
# Out:
# 'This is a test string. \t\t \n'

# %%
sentence.rstrip()
# Out:
# '\t \n This is a test string.'

# %%
#Ben Robin 8.4 self check

# %%
name='     Marge Magenta    '
name.strip()
# Out:
# 'Marge Magenta'

# %%
name.lstrip()
# Out:
# 'Marge Magenta    '

# %%
name.rstrip()
# Out:
# '     Marge Magenta'

# %%
# Ben Robin 8.5 
'happy birthday'.capitalize()
# Out:
# 'Happy birthday'

# %%
'strings: a deeper look'.title()
# Out:
# 'Strings: A Deeper Look'

# %%
# 8.5 Ben Robin self check

# %%
test_string = 'happy new year'
test_string.capitalize()
# Out:
# 'Happy new year'

# %%
test_string.title()
# Out:
# 'Happy New Year'

# %%
# Ben Robin 8.6

# %%
print(f'A: {ord("A")}; a: {ord("a")}')
# Out:
# A: 65; a: 97

# %%
'Orange' == 'orange'
# Out:
# False

# %%
'Orange' != 'orange'
# Out:
# True

# %%
'Orange' < 'orange'
# Out:
# True

# %%
'Orange' > 'orange'
# Out:
# False

# %%
'Orange' >= 'orange'
# Out:
# False

# %%
# Ben Robin 8.7 
sentence = 'to be or not to be that is the questions'
sentence.count('be')
# Out:
# 2

# %%
sentence.count('to',12)
# Out:
# 1

# %%
sentence.count('that',12,25)
# Out:
# 1

# %%
sentence.index('be')
# Out:
# 3

# %%
sentence.rindex('be')
# Out:
# 16

# %%
'that' in sentence
# Out:
# True

# %%
'THAT' in sentence
# Out:
# False

# %%
'THAT' not in sentence
# Out:
# True

# %%
sentence.startswith('to')
# Out:
# True

# %%
sentence.startswith('be')
# Out:
# False

# %%
sentence.endswith('question')
# Out:
# False

# %%
sentence.endswith('quest')
# Out:
# False

# %%
# Ben Robin 8.7 self check 
for word in 'to be or not to be that is the question'.split():
    if word.startswith('t'):
        print(word, end=" ")
# Out:
# to to that the
